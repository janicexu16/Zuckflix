# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/janicexu/netflix_titles.csv', index_col=0)
data.head()
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%                NaN
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year rating   duration  \
# show_id
# s1         August 14, 2020          2020  TV-MA  4 Seasons
# s2       December 23, 2016          2016  TV-MA     93 min
# s3       December 20, 2018          2011      R     78 min
# s4       November 16, 2017          2009  PG-13     80 min
# s5         January 1, 2020          2008  PG-13    123 min
#
#                                                  listed_in  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s2                            Dramas, International Movies
# s3                     Horror Movies, International Movies
# s4       Action & Adventure, Independent Movies, Sci-Fi...
# s5                                                  Dramas
#
#                                                description
# show_id
# s1       In a future where the elite inhabit an island ...
# s2       After a devastating earthquake hits Mexico Cit...
# s3       When an army recruit is found dead, his fellow...
# s4       In a postapocalyptic world, rag-doll robots hi...
# s5       A brilliant group of students become card-coun...

# %%
data_ratings = pd.read_csv('/Users/janicexu/titles_and_ratings.csv', index_col=0)
data_ratings.head()
# Out:
#                               imdb_rating
# title
# Money Heist: The Phenomenon        7.5/10
# Money Talks                        6.2/10
# The Money Trap                     6.3/10
# All the Boys Love Mandy Lane       5.5/10
# Monkey Planet                      8.5/10

# %%
data = data.drop_duplicates(subset=['title'])
data
# Out:
#             type                                    title           director  \
# show_id
# s1       TV Show                                       3%                NaN
# s2         Movie                                     7:19  Jorge Michel Grau
# s3         Movie                                    23:59       Gilbert Chan
# s4         Movie                                        9        Shane Acker
# s5         Movie                                       21     Robert Luketic
# ...          ...                                      ...                ...
# s7783      Movie                                     Zozo        Josef Fares
# s7784      Movie                                   Zubaan        Mozez Singh
# s7785      Movie                        Zulu Man in Japan                NaN
# s7786    TV Show                    Zumbo's Just Desserts                NaN
# s7787      Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
#                                                       cast  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                                                    ...
# s7783    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# s7784    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# s7785                                              Nasty C
# s7786                           Adriano Zumbo, Rachel Khoo
# s7787                                                  NaN
#
#                                                    country  \
# show_id
# s1                                                  Brazil
# s2                                                  Mexico
# s3                                               Singapore
# s4                                           United States
# s5                                           United States
# ...                                                    ...
# s7783    Sweden, Czech Republic, United Kingdom, Denmar...
# s7784                                                India
# s7785                                                  NaN
# s7786                                            Australia
# s7787                United Kingdom, Canada, United States
#
#                  date_added  release_year rating   duration  \
# show_id
# s1          August 14, 2020          2020  TV-MA  4 Seasons
# s2        December 23, 2016          2016  TV-MA     93 min
# s3        December 20, 2018          2011      R     78 min
# s4        November 16, 2017          2009  PG-13     80 min
# s5          January 1, 2020          2008  PG-13    123 min
# ...                     ...           ...    ...        ...
# s7783      October 19, 2020          2005  TV-MA     99 min
# s7784         March 2, 2019          2015  TV-14    111 min
# s7785    September 25, 2020          2019  TV-MA     44 min
# s7786      October 31, 2020          2019  TV-PG   1 Season
# s7787         March 1, 2020          2019  TV-MA     90 min
#
#                                                  listed_in  \
# show_id
# s1       International TV Shows, TV Dramas, TV Sci-Fi &...
# s2                            Dramas, International Movies
# s3                     Horror Movies, International Movies
# s4       Action & Adventure, Independent Movies, Sci-Fi...
# s5                                                  Dramas
# ...                                                    ...
# s7783                         Dramas, International Movies
# s7784       Dramas, International Movies, Music & Musicals
# s7785    Documentaries, International Movies, Music & M...
# s7786                   International TV Shows, Reality TV
# s7787                      Documentaries, Music & Musicals
#
#                                                description
# show_id
# s1       In a future where the elite inhabit an island ...
# s2       After a devastating earthquake hits Mexico Cit...
# s3       When an army recruit is found dead, his fellow...
# s4       In a postapocalyptic world, rag-doll robots hi...
# s5       A brilliant group of students become card-coun...
# ...                                                    ...
# s7783    When Lebanon's Civil War deprives Zozo of his ...
# s7784    A scrappy but poor boy worms his way into a ty...
# s7785    In this documentary, South African rapper Nast...
# s7786    Dessert wizard Adriano Zumbo looks for the nex...
# s7787    This documentary delves into the mystique behi...
#
# [7787 rows x 11 columns]

# %%
data = pd.merge(data, data_ratings, on = 'title')
data['imdb_value'] = data[' imdb_rating'].str[:3]
data = data.drop([4404])
counter = pd.to_numeric(data['imdb_value'], downcast='float')
print(counter)
#data[data['imdb_value']==8.1].count
# Out:
# 0       5.9
# 1       4.6
# 2       6.0
# 3       5.3
# 4       6.4
#        ...
# 4976    7.6
# 4977    4.4
# 4978    6.6
# 4979    6.1
# 4980    6.9
# Name: imdb_value, Length: 4980, dtype: float32

# %%
rating_counter = data['imdb_value'].value_counts()
print(rating_counter[rating_counter>8.0])

#data['imdb_value'] = data['imdb_value'].astype(float, errors = 'raise')
#data['imdb_value'] = data['imdb_value']>5.0

#print(data['imdb_value'])
# Out:
# 6.8    194
# 6.6    185
# 7.2    180
# 7.3    178
# 6.5    174
# 7.4    174
# 6.4    171
# 6.7    167
# 7.1    163
# 6.2    156
# 7.0    156
# 6.3    152
# 7.6    144
# 6.9    142
# 5.8    135
# 6.1    133
# 5.7    122
# 7.5    122
# 6.0    113
# 7.7    113
# 5.6    108
# 8.0    108
# 5.4     95
# 5.9     94
# 8.1     94
# 5.3     91
# 7.8     90
# 5.5     89
# 7.9     84
# 5.2     79
# 8.4     66
# 8.2     66
# 5.1     64
# 4.4     55
# 8.3     53
# 4.8     51
# 4.7     50
# 5.0     50
# 4.9     43
# 8.5     41
# 4.3     37
# 4.6     37
# 8.6     33
# 4.5     30
# 4.2     29
# 4.1     23
# 8.8     22
# 8.7     21
# 3.6     18
# 3.7     17
# 3.8     16
# 3.9     16
# 3.5     12
# 9.1     11
# 8.9     10
# 4.0     10
# 3.4     10
# 9.0      9
# Name: imdb_value, dtype: int64

# %%
plt.figure(figsize=(10,6))

x= data.type.value_counts()
sns.countplot(x= "type",data= data)

# %%
pd.crosstab(data.release_year, data.type).plot(kind='bar',figsize=(15,8))
plt.title('Movie and Tv Show Release Years')
# Out:
# Text(0.5, 1.0, 'Movie and Tv Show Release Years')

# %%
data['country'].value_counts().sort_values(ascending=False)[:5].plot.bar()
plt.title('Number of Movies By Country')
plt.xlabel('Country')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
data['rating'].value_counts().sort_values(ascending=False)[:5].plot.bar()
plt.title('Movie Total Rating Count')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#df = pd.DataFrame({'Rating':data['rating']}, index = data['country'])
#ax = df.plot.bar(rot=0)

# %%
# number movies per country
country_counter = data['country'].value_counts()
print(country_counter[country_counter>50])

axis = country_counter[country_counter>50].index
print(axis)
data_country = data[data.country.isin(axis)]

data_plot = data_country.country.value_counts()
data_plot.plot(kind ='bar')
plt.title('Number of Movies By Country Greater Than 50')
plt.xlabel('Country')
plt.ylabel('Count')
# Out:
# United States                    1992
# India                             674
# United Kingdom                    282
# Canada                            125
# Japan                              86
# South Korea                        76
# Australia                          62
# France                             55
# United Kingdom, United States      54
# Name: country, dtype: int64
# Index(['United States', 'India', 'United Kingdom', 'Canada', 'Japan',
#        'South Korea', 'Australia', 'France', 'United Kingdom, United States'],
#       dtype='object')
# Text(0, 0.5, 'Count')

# %%
#countries = ['United States', 'India', 'United Kingdom', 'Japan', 'South Korea']
#data_group = data.loc[data['country'].isin(countries)]

#group_plot = data_group['rating'].groupby(data_group['country']).value_counts()
#print(group_plot.keys)
#fig = plt.figure(figsize=(12,6))
#group_plot.plot(kind ='bar')

# %%
countries = ['United States', 'India', 'United Kingdom']
data_group = data.loc[data['country'].isin(countries)]

#print(data_group)

group_plot = data_group['rating'].groupby(data_group['country']).value_counts()
group_plot.unstack().plot(kind='bar', figsize = (12,6))

plt.title('Number of Movies by Rating Grouped by Country')
plt.xlabel('Country')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(13,8))
sns.countplot(data['rating'][:],hue=data['type'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# look at imdb_rating compared to number of movies

# %%
n= data['listed_in'].value_counts()[:20]
n

sns.barplot(x=n.values,y=n.index)

# %%
l=[]
m=[]

for i in data['duration']:
    if i[3:6]=='min':
        l.append(int(i[0:2]))
    elif i[4:7]=='min':
        l.append(int(i[0:3]))
    elif i[3:10]=='Season':
        m.append(int(i[0:2]))

#durasi movie dalam menit
plt.figure(figsize=(12,6))
#sns.set_style('darkgrid')
sns.distplot(l)
plt.xlabel('time in minutes')
plt.ylabel('% of netflix movies')
plt.title('Duration distribution of movies on netflix(in minute)')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Duration distribution of movies on netflix(in minute)')

# %%
data.groupby('type').director.value_counts()['Movie'][:10].plot(kind='bar')

# %%
director_data = data[data['director']=='Steven Spielberg']
dir_sorted = director_data.sort_values('imdb_value', ascending=False)
dir_sorted
# Out:
#        type                                              title  \
# 3393  Movie                                   Schindler's List
# 1911  Movie      Indiana Jones and the Raiders of the Lost Ark
# 1909  Movie                 Indiana Jones and the Last Crusade
# 1910  Movie                 Indiana Jones and the Last Crusade
# 793   Movie                                Catch Me If You Can
# 793                                              Dramas
# 794                                              Dramas
# 1912  Action & Adventure, Children & Family Movies, ...
# 1913  Action & Adventure, Children & Family Movies, ...
# 1914  Action & Adventure, Children & Family Movies, ...
# 2328                                             Dramas
# 3824                           Children & Family Movies
# 4798                                             Dramas
# 1779                           Children & Family Movies
# 1907  Action & Adventure, Children & Family Movies, ...
# 1908  Action & Adventure, Children & Family Movies, ...
#
#                                             description  imdb_rating  \
# 3393  Oskar Schindler becomes an unlikely humanitari...       8.9/10
# 1911  When Indiana Jones is hired by the government ...       8.4/10
# 1909  Accompanied by his father, Indiana Jones sets ...       8.2/10
# 1910  Accompanied by his father, Indiana Jones sets ...       8.2/10
# 793   An FBI agent makes it his mission to put cunni...       8.1/10
# 794   An FBI agent makes it his mission to put cunni...       8.1/10
# 1912  Indiana Jones, his young sidekick and a spoile...       7.5/10
# 1913  Indiana Jones, his young sidekick and a spoile...       7.5/10
# 1914  Indiana Jones, his young sidekick and a spoile...       7.5/10
# 2328  Director Steven Spielberg takes on the towerin...       7.3/10
# 3824  This 3-D motion capture adapts Georges Remi's ...       7.3/10
# 4798  During World War I, the bond between a young E...       7.2/10
# 1779  Peter Pan, now grown up and a workaholic, must...       6.8/10
# 1907  Indiana Jones is drawn into a Russian plot to ...       6.1/10
# 1908  Indiana Jones is drawn into a Russian plot to ...       6.1/10
#
#      imdb_value
# 3393        8.9
# 1911        8.4
# 1909        8.2
# 1910        8.2
# 793         8.1
# 794         8.1
# 1912        7.5
# 1913        7.5
# 1914        7.5
# 2328        7.3
# 3824        7.3
# 4798        7.2
# 1779        6.8
# 1907        6.1
# 1908        6.1

# %%
data.groupby('type').director.value_counts()['TV Show'][:10].plot(kind='bar')

# %%
data[data['director']=='Rob Seidenglanz']
# Out:
#          type                     title         director  \
# 1043  TV Show  DC's Legends of Tomorrow  Rob Seidenglanz
# 3265  TV Show                 Riverdale  Rob Seidenglanz
#
#                                                    cast        country  \
# 1043  Victor Garber, Brandon Routh, Caity Lotz, Fran...  United States
# 3265  K.J. Apa, Lili Reinhart, Camila Mendes, Cole S...  United States
#
#          date_added  release_year rating   duration  \
# 1043  June 10, 2020          2020  TV-14  5 Seasons
# 3265   May 14, 2020          2019  TV-14  4 Seasons
#
#                                        listed_in  \
# 1043  TV Action & Adventure, TV Sci-Fi & Fantasy
# 3265     Crime TV Shows, TV Dramas, TV Mysteries
#
#                                             description  imdb_rating  \
# 1043  A mysterious "time master" from the future uni...       6.8/10
# 3265  While navigating the troubled waters of sex, r...       6.8/10
#
#      imdb_value
# 1043        6.8
# 3265        6.8

# %%
sorted = data.sort_values('imdb_value', ascending=False)
sorted
# Out:
#          type                           title            director  \
# 3930    Movie                      The Chosen  Antonio Chavarrías
# 3929    Movie                      The Chosen  Antonio Chavarrías
# 1554    Movie                      God of War         Gordon Chan
# 3052  TV Show                 Planet Earth II                 NaN
# 707   TV Show                    Breaking Bad                 NaN
# ...       ...                             ...                 ...
# 1740    Movie                      Himmatwala          Sajid Khan
